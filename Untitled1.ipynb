# %%
var('t')
parametric_plot([2*(t-sin(t)),2*(1-cos(t))],(t,-2*pi,2*pi),figsize=15,color='yellow',title='cycloid')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('t')
parametric_plot([2*cos(t),2*sin(t)],(t,-2*pi,2*pi),figsize=15,color='turquoise')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('t')
parametric_plot([t*sin(1-t^2),t*cos(t^2)],(t,-2*pi,2*pi),figsize=5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x,y')
f(x,y)=x^2-y^3*(2-y)
implicit_plot(f,(x,-2,2),(y,0,2),figsize=3,color='maroon',plot_points=5000,gridlines='True')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('t')
parametric_plot([4*(cos(t))^3,4*(sin(t))^3],(t,-2*pi,2*pi),figsize=15,color='purple',title='Asteroid')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('t')
polar_plot (2*(1-cos(t)),(t,-2*pi,2*pi),figsize=7,color='purple',fill=2*(1+cos(t)),fillcolor='brown')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('t')
polar_plot (2*cos(3*t),(t,-2*pi,2*pi),figsize=5,color='purple',fill=2*(1+cos(t)),fillcolor='pink')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('t')
polar_plot (2*cos(4*t),(t,-2*pi,2*pi),figsize=5,color='purple',fill=2*(1+cos(t)),fillcolor='pink')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
L=[p1,p2,p3,p4]
G=graphics_array(L,1,4)
G.show(figsize=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-dc03b4f703fd> in <module>
# ----> 1 L=[p1,p2,p3,p4]
#       2 G=graphics_array(L,Integer(1),Integer(4))
#       3 G.show(figsize=Integer(10))
#
# NameError: name 'p1' is not defined
